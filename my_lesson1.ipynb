# %% [markdown]
# # Thuc hành Tri tue nhan tao buoi 1
# ## Noi dung thuc hanh
# ### In chu ra man hinh

# %%
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %% [markdown]
# ## Chay tap tin PY

# %%
# !python ex0_hello_world.py
# Out:
# Hello, Python World!

# %%
# %run ex0_hello_world.py
# Out:
# Hello, Python World!

# %% [markdown]
# ### Bai 4 Tinh toan khoa hoc

# %%
# %run ex1_calc.py
# Out:
# Calculator Basic
# Moi ban nhap so a:  20
# Moi ban nhap so b:  78
# c = 20 + 78 = 98

# %%
print("Calculator Basic")
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))
c = a + b
print("c = %d + %d = %d" % (a, b, c))
# Out:
# Calculator Basic
# Moi ban nhap so a:  10
# Moi ban nhap so b:  11
# c = 10 + 11 = 21

# %% [markdown]
# ### Bai 7 Tinh chu vi, dien tich hình tron

# %%
# %run ex3_circle.py
# Out:
# Nhap ban kinh hinh tron:
#  4
# Chu vi hinh tron:  25.1328
# Dien tich hinh tron:  50.24

# %% [markdown]
# # Ket thuc
